# %% [markdown]
# Name: Shreyas Dongre
# Roll no: 082
# Stream: CS (AI)
# Division: I
# Semester: 5th Semester
# Batch: I-3
#                                                                        Date: 14/7/2022
# Subject: DL
# ###Experiment-1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = tf.keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels) =  dataset.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
train_labels[0]
# Out:
# 9

# %%
train_labels[1]
# Out:
# 0

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
plt.imshow(train_images[2])
plt.colorbar()

# %%
labels = {0:'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',5:'Sandal',6:'Shirt',7:'Sneaker',8:'Bag',9:'Ankle boot'}

# %%
#normalizing pix vals
train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),tf.keras.layers.Dense(128,activation='relu'),tf.keras.layers.Dense(10)])

# %%
#compile the model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 7s 2ms/step - loss: 0.4996 - accuracy: 0.8247
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3755 - accuracy: 0.8640
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3362 - accuracy: 0.8762
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3132 - accuracy: 0.8845
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2945 - accuracy: 0.8910
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2785 - accuracy: 0.8959
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2666 - accuracy: 0.9006
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2552 - accuracy: 0.9046
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2452 - accuracy: 0.9071
# Epoch 10/100
# ...

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels,verbose=2)
print("\nTest Accuracy is: ",test_acc)
# Out:
# 313/313 - 1s - loss: 0.7937 - accuracy: 0.8873 - 681ms/epoch - 2ms/step
#
# Test Accuracy is:  0.8873000144958496

# %%
#NEW ACTIVATION FUNCTION 
#define model
model=tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), tf.keras.layers.Dense(128,activation='linear'),tf.keras.layers.Dense(10)])
#compile model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=200)
#predicting test accuracy
test_loss,test_acc=model.evaluate(test_images,test_labels,verbose=2)
print('Test accuracy: ',test_acc)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
# Out:
# Epoch 1/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5420 - accuracy: 0.8121
# Epoch 2/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4620 - accuracy: 0.8401
# Epoch 3/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4409 - accuracy: 0.8475
# Epoch 4/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4328 - accuracy: 0.8480
# Epoch 5/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4232 - accuracy: 0.8516
# Epoch 6/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4198 - accuracy: 0.8526
# Epoch 7/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4165 - accuracy: 0.8528
# Epoch 8/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4108 - accuracy: 0.8559
# Epoch 9/200
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4082 - accuracy: 0.8575
# Epoch 10/200
# ...

# %%
#NEW ACTIVATION FUNCTION 
#define model
model=tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), tf.keras.layers.Dense(128,activation='sigmoid'),tf.keras.layers.Dense(10)])
#compile model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=100)
#predicting test accuracy
test_loss,test_acc=model.evaluate(test_images,test_labels,verbose=2)
print('Test accuracy: ',test_acc)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5409 - accuracy: 0.8144
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3905 - accuracy: 0.8585
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3547 - accuracy: 0.8723
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3290 - accuracy: 0.8813
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3100 - accuracy: 0.8863
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2947 - accuracy: 0.8915
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2832 - accuracy: 0.8962
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2711 - accuracy: 0.9004
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2601 - accuracy: 0.9057
# Epoch 10/100
# ...

# %% [markdown]
# #Conclusion:
# 1) Activation function and number of epochs have to be selected carefully while building DL model. Some functions might give better accuracy in one model as compared to other.
